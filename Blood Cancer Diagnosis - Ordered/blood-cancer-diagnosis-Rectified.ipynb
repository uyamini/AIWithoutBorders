# %% [markdown]
# Aim:
# Finding a suitable model for classification of leukemic B-lymphoblast cells from normal B-lymphoid precursors from blood smear microscopic images.
#
# We have used a CNN model and some pretrained models like ResNet50, VGG16, VGG19 and InceptionV3 in this process which can be find in the first version.
#
# In this version, we are using Capsnet, SeResNext, DenseNet, ResNext50, VGG19 with also stacking four of these models except SeResNext. Since the observation told us that SeResNext is having the best performance of them all, so we are going to save this model for our future predictions.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
import sys
print(os.listdir("../input"))
from glob import glob
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = [10, 5]
# Any results you write to the current directory are saved as output.
# Out:
# ['blood-cancer-test-dataset', 'blood-cancer-training-dataset']

# %%
from __future__ import print_function
from __future__ import absolute_import
from __future__ import division

import warnings

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.linear_model import LogisticRegression

import itertools

import keras
from keras import utils
from keras.utils.np_utils import to_categorical
from keras.models import Sequential, Model
from keras.layers.normalization import BatchNormalization
from keras.layers import *
from keras import backend as K
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau
from keras import activations
from keras.regularizers import l2
from keras.engine.topology import get_source_inputs
# Out:
# Using TensorFlow backend.

# %%
# This cell can be used to access and use the TEST dataset available

# data = pd.read_csv("../input/blood-cancer-test-dataset/c-nmc_test_prelim_phase_data/C-NMC_test_prelim_phase_data/C-NMC_test_prelim_phase_data_labels.csv")
# print(data.head())

# baseadd = "../input/blood-cancer-test-dataset/c-nmc_test_prelim_phase_data/C-NMC_test_prelim_phase_data/C-NMC_test_prelim_phase_data"
# image_path_dict = {os.path.basename(x): x for x in glob(os.path.join(baseadd, "*.bmp"))}
# data["path"] = (data["new_names"]).map(image_path_dict.get)
# data['image'] = data['path'].map(lambda x: np.asarray(Image.open(x).resize((224, 224))))
# data["image"].shape
# print(data.head())

# data["Patient_ID"][0].split('_')
# subject_id_dict = {data["Patient_ID"][x]: data["Patient_ID"][x].split("_")[1] for x in range(len(data["Patient_ID"]))}
# image_id_dict = {data["Patient_ID"][x]: data["Patient_ID"][x].split("_")[2] for x in range(len(data["Patient_ID"]))}
# cell_id_dict = {data["Patient_ID"][x]: data["Patient_ID"][x].split("_")[3] for x in range(len(data["Patient_ID"]))}

# data["subject_id"] = data["Patient_ID"].map(subject_id_dict.get)
# data["image_id"] = data["Patient_ID"].map(image_id_dict.get)
# data["cell_no"] = data["Patient_ID"].map(cell_id_dict.get)
# # data["cell_state"] = data["Patient_ID"].map(cell_type_id_dict.get)
# subject_filter_dict = {data["subject_id"][x]: data["subject_id"][x][1:] if "H" in data["subject_id"][x] 
#                        else data["subject_id"][x] for x in range(len(data["Patient_ID"]))}
# data["subject_id"] = data["subject_id"].map(subject_filter_dict.get)
# print(data.sample(5))

# plt.imshow(data["image"][0])
# plt.axis("off")

# data["labels"].value_counts().plot(kind = "bar")
# print(data["labels"].value_counts())

# plt.scatter(data['subject_id'], data['cell_no'])
# plt.title("Subject Id distribution")

# data['subject_id'].value_counts().plot(kind = 'bar')
# plt.title("Subject Id dis")

# %% [markdown]
# ## Preprocessing the data

# %%
baseadd_tr = "../input/blood-cancer-training-dataset/c-nmc_training_data(1)/C-NMC_training_data"
image_path_dict_tr = {os.path.basename(x).split(".")[0]: x for x in glob(os.path.join(baseadd_tr, "*", "*", "*.bmp"))}

# %%
data_tr = pd.DataFrame()
password = [os.path.basename(x).split(".")[0] for x in glob(os.path.join(baseadd_tr, "*", "*", "*.bmp"))]
data_tr["Patient_ID"] = password

# %%
data_tr["path"] = data_tr["Patient_ID"].map(image_path_dict_tr.get)
data_tr['image'] = data_tr['path'].map(lambda x: np.asarray(Image.open(x).resize((100, 100))))

# %%
data_tr["Patient_ID"][0].split('_')

subject_id_dict_tr = {data_tr["Patient_ID"][x]: data_tr["Patient_ID"][x].split("_")[1] for x in range(len(data_tr["Patient_ID"]))}
image_id_dict_tr = {data_tr["Patient_ID"][x]: data_tr["Patient_ID"][x].split("_")[2] for x in range(len(data_tr["Patient_ID"]))}
cell_id_dict_tr = {data_tr["Patient_ID"][x]: data_tr["Patient_ID"][x].split("_")[3] for x in range(len(data_tr["Patient_ID"]))}

data_tr["subject_id"] = data_tr["Patient_ID"].map(subject_id_dict_tr.get)
data_tr["image_id"] = data_tr["Patient_ID"].map(image_id_dict_tr.get)
data_tr["cell_no"] = data_tr["Patient_ID"].map(cell_id_dict_tr.get)

subject_filter_dict_tr = {data_tr["subject_id"][x]: data_tr["subject_id"][x][1:] if ("H") in data_tr["subject_id"][x] 
                       else data_tr["subject_id"][x] for x in range(len(data_tr["Patient_ID"]))}
data_tr["subject_id"] = data_tr["subject_id"].map(subject_filter_dict_tr.get)

# 0 means normal cell, while 1 means a cancer diagnosed cell
label_dict = {password[x] : password[x].split("_")[-1] for x in range(len(password))}
data_tr["labels"] = data_tr["Patient_ID"].map(label_dict.get)
data_tr["labels"] = data_tr["labels"].apply(lambda x: 1 if x == 'all' else 0).astype(np.bool)
data_tr["subject_id"] = data_tr["subject_id"].apply(lambda x: "3" if x == "h3" else x)

# %%
data_tr.sample(5)
# Out:
#             Patient_ID  ...   labels
# 7136  UID_H15_12_2_hem  ...    False
# 6336   UID_13_20_2_all  ...     True
# 7048    UID_37_3_3_all  ...     True
# 9457   UID_52_17_8_all  ...     True
# 4637  UID_H23_12_8_hem  ...    False
#
# [5 rows x 7 columns]

# %%
# Deleting dicts and list whose work is done in order to free our memory.
del image_path_dict_tr
del password
del subject_id_dict_tr
del image_id_dict_tr
del cell_id_dict_tr
del subject_filter_dict_tr
del baseadd_tr
del label_dict

# %%
plt.imshow(data_tr["image"][4])
plt.axis("off")
# Out:
# (-0.5, 99.5, 99.5, -0.5)

# %%
data_tr["labels"].value_counts().plot(kind = "bar")
data_tr["labels"].value_counts()
# Out:
# True     7272
# False    3389
# Name: labels, dtype: int64

# %%
plt.rcParams['figure.figsize'] = [10, 5]
data_tr['subject_id'].value_counts().plot(kind = 'bar')
plt.title("Subject Id distribution")
# Out:
# Text(0.5, 1.0, 'Subject Id distribution')

# %%
data_tr["cell_no"] = data_tr["cell_no"].astype(np.int32)
data_tr["subject_id"] = data_tr["subject_id"].astype(np.int32)
data_tr["image_id"] = data_tr["image_id"].astype(np.int32)
data_tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10661 entries, 0 to 10660
# Data columns (total 7 columns):
# Patient_ID    10661 non-null object
# path          10661 non-null object
# image         10661 non-null object
# subject_id    10661 non-null int32
# image_id      10661 non-null int32
# cell_no       10661 non-null int32
# labels        10661 non-null bool
# dtypes: bool(1), int32(3), object(3)
# memory usage: 385.3+ KB

# %%
X = data_tr.drop(["labels"], axis = 1)
y = data_tr["labels"]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

y_train.value_counts().plot(kind = "bar")

print("%age of label value 0 in training dataset", 
      y_train.value_counts()[0]/(y_train.value_counts()[0]+y_train.value_counts()[1]))
print("%age of label value 0 in test dataset", 
      y_test.value_counts()[0]/(y_test.value_counts()[0]+y_test.value_counts()[1]))

del X, y
# Out:
# %age of label value 0 in training dataset 0.3169559099437148
# %age of label value 0 in test dataset 0.32161275199249884

# %%
y_test.value_counts().plot(kind = "bar")

# %% [markdown]
# Image was reshaped to (100, 100, 3) as at more than that, the kernel was crashing everytime.

# %%
# Normalization
x_train = np.asarray(x_train['image'].tolist())
x_test = np.asarray(x_test['image'].tolist())

x_train_mean = np.mean(x_train)
x_test_mean = np.mean(x_test)

x_train_std = np.std(x_train)
x_test_std = np.std(x_test)

x_train = (x_train - x_train_mean)/x_train_std
x_test = (x_test - x_test_mean)/x_test_std

y_dopetest = y_test
# Label Encoding
y_train = to_categorical(y_train, num_classes = 2)
y_test = to_categorical(y_test, num_classes = 2)

# Reshape images in 3 dimensions
x_train = x_train.reshape(x_train.shape[0], *(100, 100, 3))
x_test = x_test.reshape(x_test.shape[0], *(100, 100, 3))
x_train.shape
# Out:
# (8528, 100, 100, 3)

# %% [markdown]
# ## Defining models to train on our dataset

# %%
input_shape = (100, 100, 3)
num_classes = 2
epochs = 20
# Set learning rate annealer
learning_rate_reduction = ReduceLROnPlateau(monitor = 'val_acc', patience = 3, verbose = 1, 
                                           factor = 0.5, min_lr = 0.00001)

# Data Augmentation
datagen = ImageDataGenerator(featurewise_center = False, samplewise_center = True,
                            featurewise_std_normalization = False, samplewise_std_normalization = False, 
                            zca_whitening = False, rotation_range = 0, zoom_range = 0.3, 
                            width_shift_range = 0.2, height_shift_range = 0.2, horizontal_flip = False, 
                            vertical_flip = False, rescale = 1./255)
datagen.fit(x_train)
print(x_test.shape)
for i in range(len(x_test)):
    # this is what you are looking for
    x_test[i] = datagen.standardize(x_test[i])
print(x_test.shape)
# Out:
# (2133, 100, 100, 3)
# (2133, 100, 100, 3)

# %% [markdown]
# Defining and fitting Capsule network

# %%
# the squashing function.
# we use 0.5 instead of 1 in hinton's paper.
# if 1, the norm of vector will be zoomed out.
# if 0.5, the norm will be zoomed in while original norm is less than 0.5
# and be zoomed out while original norm is greater than 0.5.
def squash(x, axis=-1):
    s_squared_norm = K.sum(K.square(x), axis, keepdims=True) + K.epsilon()
    scale = K.sqrt(s_squared_norm) / (0.5 + s_squared_norm)
    return scale * x


# define our own softmax function instead of K.softmax
# because K.softmax can not specify axis.
def softmax(x, axis=-1):
    ex = K.exp(x - K.max(x, axis=axis, keepdims=True))
    return ex / K.sum(ex, axis=axis, keepdims=True)


# define the margin loss like hinge loss
def margin_loss(y_true, y_pred):
    lamb, margin = 0.5, 0.1
    return K.sum(y_true * K.square(K.relu(1 - margin - y_pred)) + lamb * (
        1 - y_true) * K.square(K.relu(y_pred - margin)), axis=-1)


class Capsule(Layer):
    """A Capsule Implement with Pure Keras
    There are two vesions of Capsule.
    One is like dense layer (for the fixed-shape input),
    and the other is like time distributed dense (for various length input).

    The input shape of Capsule must be (batch_size,
                                        input_num_capsule,
                                        input_dim_capsule
                                       )
    and the output shape is (batch_size,
                             num_capsule,
                             dim_capsule
                            )

    Capsule Implement is from https://github.com/bojone/Capsule/
    Capsule Paper: https://arxiv.org/abs/1710.09829
    """

    def __init__(self,
                 num_capsule,
                 dim_capsule,
                 routings=3,
                 share_weights=True,
                 activation='squash',
                 **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.share_weights = share_weights
        if activation == 'squash':
            self.activation = squash
        else:
            self.activation = activations.get(activation)

    def build(self, input_shape):
        input_dim_capsule = input_shape[-1]
        if self.share_weights:
            self.kernel = self.add_weight(
                name='capsule_kernel',
                shape=(1, input_dim_capsule,
                       self.num_capsule * self.dim_capsule),
                initializer='glorot_uniform',
                trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.kernel = self.add_weight(
                name='capsule_kernel',
                shape=(input_num_capsule, input_dim_capsule,
                       self.num_capsule * self.dim_capsule),
                initializer='glorot_uniform',
                trainable=True)

    def call(self, inputs):
        """Following the routing algorithm from Hinton's paper,
        but replace b = b + <u,v> with b = <u,v>.

        This change can improve the feature representation of Capsule.

        However, you can replace
            b = K.batch_dot(outputs, hat_inputs, [2, 3])
        with
            b += K.batch_dot(outputs, hat_inputs, [2, 3])
        to realize a standard routing.
        """

        if self.share_weights:
            hat_inputs = K.conv1d(inputs, self.kernel)
        else:
            hat_inputs = K.local_conv1d(inputs, self.kernel, [1], [1])

        batch_size = K.shape(inputs)[0]
        input_num_capsule = K.shape(inputs)[1]
        hat_inputs = K.reshape(hat_inputs,
                               (batch_size, input_num_capsule,
                                self.num_capsule, self.dim_capsule))
        hat_inputs = K.permute_dimensions(hat_inputs, (0, 2, 1, 3))

        b = K.zeros_like(hat_inputs[:, :, :, 0])
        for i in range(self.routings):
            c = softmax(b, 1)
            o = self.activation(K.batch_dot(c, hat_inputs, [2, 2]))
            if i < self.routings - 1:
                b = K.batch_dot(o, hat_inputs, [2, 3])
                if K.backend() == 'keras':
                    o = K.sum(o, axis=1)

        return o

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)


batch_size = 128
num_classes = 2
# A common Conv2D model
input_image = Input(shape=(None, None, 3))
x = Conv2D(64, (3, 3), activation='relu')(input_image)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = AveragePooling2D((2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu')(x)
x = Conv2D(128, (3, 3), activation='relu')(x)
x = AveragePooling2D((2, 2))(x)


"""now we reshape it as (batch_size, input_num_capsule, input_dim_capsule)
then connect a Capsule layer.

the output of final model is the lengths of 10 Capsule, whose dim=16.

the length of Capsule is the proba,
so the problem becomes a 10 two-classification problem.
"""

x = Reshape((-1, 128))(x)
capsule = Capsule(2, 16, 3, True)(x)
capsule = Dense(1, activation = 'sigmoid')(capsule)
output = Lambda(lambda z: K.sqrt(K.sum(K.square(z), 2)))(capsule)
model_caps = Model(inputs=input_image, outputs=output)

# we use a margin loss
model_caps.compile(loss=margin_loss, optimizer= optimizers.Adam(lr = 0.001), metrics=['mae', 'acc'])
model_caps.summary()

# we can compare the performance with or without data augmentation
data_augmentation = False

if not data_augmentation:
    print('Not using data augmentation.')
    history = model_caps.fit_generator(
        datagen.flow(x_train, y_train, batch_size=batch_size),
        epochs= epochs,
        validation_data= (x_test, y_test),
        steps_per_epoch = x_train.shape[0] // batch_size)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen1 = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by dataset std
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        zca_epsilon=1e-06,  # epsilon for ZCA whitening
        rotation_range=0,  # randomly rotate images in 0 to 180 degrees
        width_shift_range=0.1,  # randomly shift images horizontally
        height_shift_range=0.1,  # randomly shift images vertically
        shear_range=0.,  # set range for random shear
        zoom_range=0.,  # set range for random zoom
        channel_shift_range=0.,  # set range for random channel shifts
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        cval=0.,  # value used for fill_mode = "constant"
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for feature-wise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    history = model.fit_generator(
        datagen1.flow(x_train, y_train, batch_size=batch_size),
        epochs= epochs,
        validation_data=(x_test, y_test),
        steps_per_epoch = x_train.shape[0] // batch_size,
        workers=4)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, None, None, 3)     0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, None, None, 64)    1792
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, None, None, 64)    36928
# _________________________________________________________________
# average_pooling2d_1 (Average (None, None, None, 64)    0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, None, None, 128)   73856
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, None, None, 128)   147584
# _________________________________________________________________
# average_pooling2d_2 (Average (None, None, None, 128)   0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, None, 128)         0
# _________________________________________________________________
# capsule_1 (Capsule)          (None, 2, 16)             4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 2, 1)              17
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 2)                 0
# =================================================================
# Total params: 264,273
# Trainable params: 264,273
# Non-trainable params: 0
# _________________________________________________________________
# Not using data augmentation.
# Epoch 1/20
# 66/66 [==============================] - 22s 332ms/step - loss: 0.1886 - mean_absolute_error: 0.4507 - acc: 0.6799 - val_loss: 0.1878 - val_mean_absolute_error: 0.4555 - val_acc: 0.6784
# Epoch 2/20
# 66/66 [==============================] - 18s 279ms/step - loss: 0.1676 - mean_absolute_error: 0.4217 - acc: 0.7149 - val_loss: 0.1459 - val_mean_absolute_error: 0.3865 - val_acc: 0.7736
# Epoch 3/20
# 66/66 [==============================] - 18s 280ms/step - loss: 0.1568 - mean_absolute_error: 0.3987 - acc: 0.7420 - val_loss: 0.1430 - val_mean_absolute_error: 0.3927 - val_acc: 0.7834
# Epoch 4/20
# 66/66 [==============================] - 18s 278ms/step - loss: 0.1554 - mean_absolute_error: 0.3946 - acc: 0.7475 - val_loss: 0.1481 - val_mean_absolute_error: 0.3816 - val_acc: 0.7586
# Epoch 5/20
# 66/66 [==============================] - 18s 276ms/step - loss: 0.1536 - mean_absolute_error: 0.3908 - acc: 0.7482 - val_loss: 0.1416 - val_mean_absolute_error: 0.3828 - val_acc: 0.7834
# Epoch 6/20
# 66/66 [==============================] - 18s 278ms/step - loss: 0.1536 - mean_absolute_error: 0.3896 - acc: 0.7489 - val_loss: 0.1413 - val_mean_absolute_error: 0.3886 - val_acc: 0.7792
# Epoch 7/20
# 66/66 [==============================] - 18s 277ms/step - loss: 0.1549 - mean_absolute_error: 0.3930 - acc: 0.7435 - val_loss: 0.1458 - val_mean_absolute_error: 0.3866 - val_acc: 0.7684
# Epoch 8/20
# 66/66 [==============================] - 18s 277ms/step - loss: 0.1518 - mean_absolute_error: 0.3862 - acc: 0.7514 - val_loss: 0.1406 - val_mean_absolute_error: 0.3886 - val_acc: 0.7820
# Epoch 9/20
# 66/66 [==============================] - 19s 284ms/step - loss: 0.1511 - mean_absolute_error: 0.3858 - acc: 0.7524 - val_loss: 0.1406 - val_mean_absolute_error: 0.3869 - val_acc: 0.7792
# Epoch 10/20
# 66/66 [==============================] - 19s 282ms/step - loss: 0.1536 - mean_absolute_error: 0.3897 - acc: 0.7482 - val_loss: 0.1518 - val_mean_absolute_error: 0.3715 - val_acc: 0.7506
# Epoch 11/20
# 66/66 [==============================] - 19s 281ms/step - loss: 0.1536 - mean_absolute_error: 0.3895 - acc: 0.7446 - val_loss: 0.1413 - val_mean_absolute_error: 0.3806 - val_acc: 0.7806
# Epoch 12/20
# 66/66 [==============================] - 18s 279ms/step - loss: 0.1534 - mean_absolute_error: 0.3880 - acc: 0.7545 - val_loss: 0.1413 - val_mean_absolute_error: 0.3801 - val_acc: 0.7801
# Epoch 13/20
# 66/66 [==============================] - 19s 295ms/step - loss: 0.1518 - mean_absolute_error: 0.3857 - acc: 0.7505 - val_loss: 0.1420 - val_mean_absolute_error: 0.3823 - val_acc: 0.7782
# Epoch 14/20
# 66/66 [==============================] - 20s 297ms/step - loss: 0.1522 - mean_absolute_error: 0.3888 - acc: 0.7513 - val_loss: 0.1435 - val_mean_absolute_error: 0.3748 - val_acc: 0.7693
# Epoch 15/20
# 66/66 [==============================] - 20s 298ms/step - loss: 0.1533 - mean_absolute_error: 0.3871 - acc: 0.7520 - val_loss: 0.1417 - val_mean_absolute_error: 0.3838 - val_acc: 0.7792
# Epoch 16/20
# 66/66 [==============================] - 19s 282ms/step - loss: 0.1521 - mean_absolute_error: 0.3871 - acc: 0.7517 - val_loss: 0.1481 - val_mean_absolute_error: 0.3748 - val_acc: 0.7562
# Epoch 17/20
# 66/66 [==============================] - 18s 278ms/step - loss: 0.1539 - mean_absolute_error: 0.3896 - acc: 0.7459 - val_loss: 0.1484 - val_mean_absolute_error: 0.3775 - val_acc: 0.7553
# Epoch 18/20
# 66/66 [==============================] - 18s 279ms/step - loss: 0.1519 - mean_absolute_error: 0.3862 - acc: 0.7483 - val_loss: 0.1428 - val_mean_absolute_error: 0.3810 - val_acc: 0.7707
# Epoch 19/20
# 66/66 [==============================] - 19s 283ms/step - loss: 0.1521 - mean_absolute_error: 0.3858 - acc: 0.7551 - val_loss: 0.1402 - val_mean_absolute_error: 0.3851 - val_acc: 0.7843
# Epoch 20/20
# 66/66 [==============================] - 18s 279ms/step - loss: 0.1498 - mean_absolute_error: 0.3825 - acc: 0.7535 - val_loss: 0.1435 - val_mean_absolute_error: 0.3769 - val_acc: 0.7707

# %%
plt.rcParams['figure.figsize'] = [10, 8]
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.rcParams['figure.figsize'] = [10, 8]
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %% [markdown]
# ### SeResNext model

# %%
input_shape = (100, 100, 3)
num_classes = 2
batch_size = 128
# Data Augmentation
datagen = ImageDataGenerator(featurewise_center = False, samplewise_center = True,
                            featurewise_std_normalization = False, samplewise_std_normalization = True, 
                            zca_whitening = False, rotation_range = 0.3, zoom_range = 0.3, 
                            width_shift_range = 0.2, height_shift_range = 0.2, horizontal_flip = True, 
                            vertical_flip = False, rescale = 1./255)
datagen.fit(x_train)
# print(datagen.mean, datagen.std)
# datagen.standardize(x_test)
print(x_test.shape)
for i in range(len(x_test)):
    # this is what you are looking for
    x_test[i] = datagen.standardize(x_test[i])
print(x_test.shape)
# Out:
# (2133, 100, 100, 3)
# (2133, 100, 100, 3)

# %%
batch_size = 128

class SEResNeXt(object):
    def __init__(self, size= 100, num_classes= 2, depth=32, reduction_ratio=4, num_split=8, num_block=3):
        self.depth = depth  # number of channels
        self.ratio = reduction_ratio  # ratio of channel reduction in SE module
        self.num_split = num_split  # number of splitting trees for ResNeXt (so called cardinality)
        self.num_block = num_block  # number of residual blocks
        if K.image_data_format() == 'channels_first':
            self.channel_axis = 1
        else:
            self.channel_axis = 3
        self.model_senet = Sequential()
        self.model_senet = self.build_model(Input(shape=(size,size,3)), num_classes)
        print(self.model_senet.summary())
        self.model_senet.compile(optimizer = "Adamax", loss = "categorical_crossentropy", metrics = ["accuracy"])
        self.hist = self.model_senet.fit_generator(
        datagen.flow(x_train, y_train, batch_size=batch_size), epochs=epochs,
        validation_data=(x_test, y_test), steps_per_epoch = x_train.shape[0] // batch_size,
            callbacks=[keras.callbacks.ModelCheckpoint('mySenetModel.hdf5', monitor='val_acc', 
                                                       verbose=0, save_best_only=True)], workers=4)
        print(self.hist)
    
    def conv_bn(self, x, filters, kernel_size, stride, padding='same'):
        '''
        Combination of Conv and BN layers since these always appear together.
        '''
        x = Conv2D(filters=filters, kernel_size=[kernel_size, kernel_size],
                   strides=[stride, stride], padding=padding)(x)
        x = BatchNormalization()(x)
        
        return x
    
    def activation(self, x, func='relu'):
        '''
        Activation layer.
        '''
        return Activation(func)(x)
    
    def channel_zeropad(self, x):
        '''
        Zero-padding for channle dimensions.
        Note that padded channles are added like (Batch, H, W, 2/x + x + 2/x).
        '''
        shape = list(x.shape)
        y = K.zeros_like(x)
        
        if self.channel_axis == 3:
            y = y[:, :, :, :shape[self.channel_axis] // 2]
        else:
            y = y[:, :shape[self.channel_axis] // 2, :, :]
        
        return concatenate([y, x, y], self.channel_axis)
    
    def channel_zeropad_output(self, input_shape):
        '''
        Function for setting a channel dimension for zero padding.
        '''
        shape = list(input_shape)
        shape[self.channel_axis] *= 2

        return tuple(shape)
    
    def initial_layer(self, inputs):
        '''
        Initial layers includes {conv, BN, relu}.
        '''
        x = self.conv_bn(inputs, self.depth, 3, 1)
        x = self.activation(x)
        
        return x
    
    def transform_layer(self, x, stride):
        '''
        Transform layer has 2 {conv, BN, relu}.
        '''
        x = self.conv_bn(x, self.depth, 1, 1)
        x = self.activation(x)
        
        x = self.conv_bn(x, self.depth, 3, stride)
        x = self.activation(x)
        
        return x
        
    def split_layer(self, x, stride):
        '''
        Parallel operation of transform layers for ResNeXt structure.
        '''
        splitted_branches = list()
        for i in range(self.num_split):
            branch = self.transform_layer(x, stride)
            splitted_branches.append(branch)
        
        return concatenate(splitted_branches, axis=self.channel_axis)
    
    def squeeze_excitation_layer(self, x, out_dim):
        '''
        SE module performs inter-channel weighting.
        '''
        squeeze = GlobalAveragePooling2D()(x)
        
        excitation = Dense(units=out_dim // self.ratio)(squeeze)
        excitation = self.activation(excitation)
        excitation = Dense(units=out_dim)(excitation)
        excitation = self.activation(excitation, 'sigmoid')
        excitation = Reshape((1,1,out_dim))(excitation)
        
        scale = multiply([x,excitation])
        
        return scale
    
    def residual_layer(self, x, out_dim):
        '''
        Residual block.
        '''
        for i in range(self.num_block):
            input_dim = int(np.shape(x)[-1])
            
            if input_dim * 2 == out_dim:
                flag = True
                stride = 2
            else:
                flag = False
                stride = 1
            
            subway_x = self.split_layer(x, stride)
            subway_x = self.conv_bn(subway_x, out_dim, 1, 1)
            subway_x = self.squeeze_excitation_layer(subway_x, out_dim)
            
            if flag:
                pad_x = AveragePooling2D(pool_size=(2,2), strides=(2,2), padding='same')(x)
                pad_x = Lambda(self.channel_zeropad, output_shape=self.channel_zeropad_output)(pad_x)
            else:
                pad_x = x
            
            x = self.activation(add([pad_x, subway_x]))
                
        return x
    
    def build_model(self, inputs, num_classes):
        '''
        Build a SENet model.
        '''
        x = self.initial_layer(inputs)
        
        x = self.residual_layer(x, out_dim=64)
        x = self.residual_layer(x, out_dim=128)
        x = self.residual_layer(x, out_dim=256)
        
        x = GlobalAveragePooling2D()(x)
        x = Dense(units=num_classes, activation='softmax')(x)
        
        return Model(inputs, x)

# %%
model_senet = SEResNeXt()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 100, 100, 3)  0
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 100, 100, 32) 896         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 100, 100, 32) 128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 100, 100, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 100, 100, 32) 1056        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 100, 100, 32) 1056        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 100, 100, 32) 1056        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 100, 100, 32) 1056        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 100, 100, 32) 1056        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 100, 100, 32) 1056        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 100, 100, 32) 1056        activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 100, 100, 32) 1056        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 100, 100, 32) 128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 100, 100, 32) 128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 100, 100, 32) 128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 100, 100, 32) 128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 100, 100, 32) 128         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 100, 100, 32) 128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 100, 100, 32) 128         conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 100, 100, 32) 128         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 100, 100, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 100, 100, 32) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 100, 100, 32) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 100, 100, 32) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 100, 100, 32) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 100, 100, 32) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 100, 100, 32) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 100, 100, 32) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 50, 50, 32)   9248        activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 50, 50, 32)   9248        activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 50, 50, 32)   9248        activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 50, 50, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 50, 50, 32)   9248        activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 50, 50, 32)   9248        activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 50, 50, 32)   9248        activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 50, 50, 32)   9248        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 50, 50, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 50, 50, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 50, 50, 32)   128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 50, 50, 32)   128         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 50, 50, 32)   128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 50, 50, 32)   128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 50, 50, 32)   128         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 50, 50, 32)   128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 50, 50, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 50, 50, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 50, 50, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 50, 50, 32)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 50, 50, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 50, 50, 32)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 50, 50, 32)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 50, 50, 32)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 50, 50, 256)  0           activation_3[0][0]
#                                                                  activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_9[0][0]
#                                                                  activation_11[0][0]
#                                                                  activation_13[0][0]
#                                                                  activation_15[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 50, 50, 64)   16448       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 50, 50, 64)   256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 64)           0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 16)           1040        global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 16)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           1088        activation_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 64)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 50, 50, 32)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 64)     0           activation_19[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 50, 50, 64)   0           average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 50, 50, 64)   0           batch_normalization_18[0][0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 50, 50, 64)   0           lambda_2[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 50, 50, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 50, 50, 32)   2080        activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 50, 50, 32)   2080        activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 50, 50, 32)   2080        activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 50, 50, 32)   2080        activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 50, 50, 32)   2080        activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 50, 50, 32)   2080        activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 50, 50, 32)   2080        activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 50, 50, 32)   2080        activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 50, 50, 32)   128         conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 50, 50, 32)   128         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 50, 50, 32)   128         conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 50, 50, 32)   128         conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 50, 50, 32)   128         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 50, 50, 32)   128         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 50, 50, 32)   128         conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 50, 50, 32)   128         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 50, 50, 32)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 50, 50, 32)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 50, 50, 32)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 50, 50, 32)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 50, 50, 32)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 50, 50, 32)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 50, 50, 32)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 50, 50, 32)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 50, 50, 32)   9248        activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 50, 50, 32)   9248        activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 50, 50, 32)   9248        activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 50, 50, 32)   9248        activation_27[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 50, 50, 32)   9248        activation_29[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 50, 50, 32)   9248        activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 50, 50, 32)   9248        activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 50, 50, 32)   9248        activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 50, 50, 32)   128         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 50, 50, 32)   128         conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 50, 50, 32)   128         conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 50, 50, 32)   128         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 50, 50, 32)   128         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 50, 50, 32)   128         conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 50, 50, 32)   128         conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 50, 50, 32)   128         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 50, 50, 32)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 50, 50, 32)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 50, 50, 32)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 50, 50, 32)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 50, 50, 32)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 50, 50, 32)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 50, 50, 32)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 50, 50, 32)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 50, 50, 256)  0           activation_22[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_26[0][0]
#                                                                  activation_28[0][0]
#                                                                  activation_30[0][0]
#                                                                  activation_32[0][0]
#                                                                  activation_34[0][0]
#                                                                  activation_36[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 50, 50, 64)   16448       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 50, 50, 64)   256         conv2d_39[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 64)           0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 16)           1040        global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 16)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           1088        activation_37[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 64)           0           dense_5[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 64)     0           activation_38[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 50, 50, 64)   0           batch_normalization_35[0][0]
#                                                                  reshape_3[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 50, 50, 64)   0           activation_20[0][0]
#                                                                  multiply_2[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 50, 50, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 50, 50, 32)   2080        activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 50, 50, 32)   2080        activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 50, 50, 32)   2080        activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 50, 50, 32)   2080        activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 50, 50, 32)   2080        activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 50, 50, 32)   2080        activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 50, 50, 32)   2080        activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 50, 50, 32)   2080        activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 50, 50, 32)   128         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 50, 50, 32)   128         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 50, 50, 32)   128         conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 50, 50, 32)   128         conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 50, 50, 32)   128         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 50, 50, 32)   128         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 50, 50, 32)   128         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 50, 50, 32)   128         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 50, 50, 32)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 50, 50, 32)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 50, 50, 32)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 50, 50, 32)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 50, 50, 32)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 50, 50, 32)   0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 50, 50, 32)   0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 50, 50, 32)   0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 50, 50, 32)   9248        activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 50, 50, 32)   9248        activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 50, 50, 32)   9248        activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 50, 50, 32)   9248        activation_46[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 50, 50, 32)   9248        activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 50, 50, 32)   9248        activation_50[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 50, 50, 32)   9248        activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 50, 50, 32)   9248        activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 50, 50, 32)   128         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 50, 50, 32)   128         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 50, 50, 32)   128         conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 50, 50, 32)   128         conv2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 50, 50, 32)   128         conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 50, 50, 32)   128         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 50, 50, 32)   128         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 50, 50, 32)   128         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 50, 50, 32)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 50, 50, 32)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 50, 50, 32)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 50, 50, 32)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 50, 50, 32)   0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 50, 50, 32)   0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 50, 50, 32)   0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 50, 50, 32)   0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 50, 50, 256)  0           activation_41[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_45[0][0]
#                                                                  activation_47[0][0]
#                                                                  activation_49[0][0]
#                                                                  activation_51[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 50, 50, 64)   16448       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 50, 50, 64)   256         conv2d_56[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 64)           0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 16)           1040        global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 16)           0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           1088        activation_56[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 64)           0           dense_7[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 1, 64)     0           activation_57[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 50, 50, 64)   0           batch_normalization_52[0][0]
#                                                                  reshape_4[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 50, 50, 64)   0           activation_39[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 50, 50, 64)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 50, 50, 32)   2080        activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 50, 50, 32)   2080        activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 50, 50, 32)   2080        activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 50, 50, 32)   2080        activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 50, 50, 32)   2080        activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 50, 50, 32)   2080        activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 50, 50, 32)   2080        activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 50, 50, 32)   2080        activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 50, 50, 32)   128         conv2d_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 50, 50, 32)   128         conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 50, 50, 32)   128         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 50, 50, 32)   128         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 50, 50, 32)   128         conv2d_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 50, 50, 32)   128         conv2d_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 50, 50, 32)   128         conv2d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 50, 50, 32)   128         conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 50, 50, 32)   0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 50, 50, 32)   0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 50, 50, 32)   0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 50, 50, 32)   0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 50, 50, 32)   0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 50, 50, 32)   0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 50, 50, 32)   0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 50, 50, 32)   0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 25, 25, 32)   9248        activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 25, 25, 32)   9248        activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 25, 25, 32)   9248        activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 25, 25, 32)   9248        activation_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 25, 25, 32)   9248        activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 25, 25, 32)   9248        activation_69[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 25, 25, 32)   9248        activation_71[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 25, 25, 32)   9248        activation_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 25, 25, 32)   128         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 25, 25, 32)   128         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 25, 25, 32)   128         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 25, 25, 32)   128         conv2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 25, 25, 32)   128         conv2d_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 25, 25, 32)   128         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 25, 25, 32)   128         conv2d_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 25, 25, 32)   128         conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 25, 25, 32)   0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 13, 13, 32)   8224        activation_153[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 13, 13, 32)   8224        activation_153[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 13, 13, 32)   8224        activation_153[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 13, 13, 32)   8224        activation_153[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 13, 13, 32)   8224        activation_153[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 13, 13, 32)   8224        activation_153[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 13, 13, 32)   8224        activation_153[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 13, 13, 32)   128         conv2d_142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 13, 13, 32)   128         conv2d_144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 13, 13, 32)   128         conv2d_146[0][0]
# __________________________________________________________________________________________________
# batch_normalization_144 (BatchN (None, 13, 13, 32)   128         conv2d_148[0][0]
# __________________________________________________________________________________________________
# batch_normalization_146 (BatchN (None, 13, 13, 32)   128         conv2d_150[0][0]
# __________________________________________________________________________________________________
# batch_normalization_148 (BatchN (None, 13, 13, 32)   128         conv2d_152[0][0]
# __________________________________________________________________________________________________
# batch_normalization_150 (BatchN (None, 13, 13, 32)   128         conv2d_154[0][0]
# __________________________________________________________________________________________________
# batch_normalization_152 (BatchN (None, 13, 13, 32)   128         conv2d_156[0][0]
# __________________________________________________________________________________________________
# activation_154 (Activation)     (None, 13, 13, 32)   0           batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# activation_156 (Activation)     (None, 13, 13, 32)   0           batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# activation_158 (Activation)     (None, 13, 13, 32)   0           batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# activation_160 (Activation)     (None, 13, 13, 32)   0           batch_normalization_144[0][0]
# __________________________________________________________________________________________________
# activation_162 (Activation)     (None, 13, 13, 32)   0           batch_normalization_146[0][0]
# __________________________________________________________________________________________________
# activation_164 (Activation)     (None, 13, 13, 32)   0           batch_normalization_148[0][0]
# __________________________________________________________________________________________________
# activation_166 (Activation)     (None, 13, 13, 32)   0           batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# activation_168 (Activation)     (None, 13, 13, 32)   0           batch_normalization_152[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 13, 13, 32)   9248        activation_154[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 13, 13, 32)   9248        activation_156[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 13, 13, 32)   9248        activation_158[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 13, 13, 32)   9248        activation_160[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 13, 13, 32)   9248        activation_162[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 13, 13, 32)   9248        activation_164[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 13, 13, 32)   9248        activation_166[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 13, 13, 32)   9248        activation_168[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 13, 13, 32)   128         conv2d_143[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 13, 13, 32)   128         conv2d_145[0][0]
# __________________________________________________________________________________________________
# batch_normalization_143 (BatchN (None, 13, 13, 32)   128         conv2d_147[0][0]
# __________________________________________________________________________________________________
# batch_normalization_145 (BatchN (None, 13, 13, 32)   128         conv2d_149[0][0]
# __________________________________________________________________________________________________
# batch_normalization_147 (BatchN (None, 13, 13, 32)   128         conv2d_151[0][0]
# __________________________________________________________________________________________________
# batch_normalization_149 (BatchN (None, 13, 13, 32)   128         conv2d_153[0][0]
# __________________________________________________________________________________________________
# batch_normalization_151 (BatchN (None, 13, 13, 32)   128         conv2d_155[0][0]
# __________________________________________________________________________________________________
# batch_normalization_153 (BatchN (None, 13, 13, 32)   128         conv2d_157[0][0]
# __________________________________________________________________________________________________
# activation_155 (Activation)     (None, 13, 13, 32)   0           batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# activation_157 (Activation)     (None, 13, 13, 32)   0           batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# activation_159 (Activation)     (None, 13, 13, 32)   0           batch_normalization_143[0][0]
# __________________________________________________________________________________________________
# activation_161 (Activation)     (None, 13, 13, 32)   0           batch_normalization_145[0][0]
# __________________________________________________________________________________________________
# activation_163 (Activation)     (None, 13, 13, 32)   0           batch_normalization_147[0][0]
# __________________________________________________________________________________________________
# activation_165 (Activation)     (None, 13, 13, 32)   0           batch_normalization_149[0][0]
# __________________________________________________________________________________________________
# activation_167 (Activation)     (None, 13, 13, 32)   0           batch_normalization_151[0][0]
# __________________________________________________________________________________________________
# activation_169 (Activation)     (None, 13, 13, 32)   0           batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 13, 13, 256)  0           activation_155[0][0]
#                                                                  activation_157[0][0]
#                                                                  activation_159[0][0]
#                                                                  activation_161[0][0]
#                                                                  activation_163[0][0]
#                                                                  activation_165[0][0]
#                                                                  activation_167[0][0]
#                                                                  activation_169[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 13, 13, 256)  65792       concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_154 (BatchN (None, 13, 13, 256)  1024        conv2d_158[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_9 (Glo (None, 256)          0           batch_normalization_154[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 64)           16448       global_average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# activation_170 (Activation)     (None, 64)           0           dense_18[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 256)          16640       activation_170[0][0]
# __________________________________________________________________________________________________
# activation_171 (Activation)     (None, 256)          0           dense_19[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 1, 1, 256)    0           activation_171[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 13, 13, 256)  0           batch_normalization_154[0][0]
#                                                                  reshape_10[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 13, 13, 256)  0           activation_153[0][0]
#                                                                  multiply_9[0][0]
# __________________________________________________________________________________________________
# activation_172 (Activation)     (None, 13, 13, 256)  0           add_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_10 (Gl (None, 256)          0           activation_172[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 2)            514         global_average_pooling2d_10[0][0]
# ==================================================================================================
# Total params: 1,456,338
# Trainable params: 1,444,370
# Non-trainable params: 11,968
# __________________________________________________________________________________________________
# None
# Epoch 1/20
# 66/66 [==============================] - 101s 2s/step - loss: 0.5106 - acc: 0.7669 - val_loss: 0.6835 - val_acc: 0.7164
# Epoch 2/20
# 66/66 [==============================] - 52s 795ms/step - loss: 0.3833 - acc: 0.8326 - val_loss: 1.0565 - val_acc: 0.6807
# Epoch 3/20
# 66/66 [==============================] - 52s 789ms/step - loss: 0.3446 - acc: 0.8580 - val_loss: 0.4021 - val_acc: 0.8172
# Epoch 4/20
# 66/66 [==============================] - 52s 790ms/step - loss: 0.3139 - acc: 0.8701 - val_loss: 0.7412 - val_acc: 0.6821
# Epoch 5/20
# 66/66 [==============================] - 52s 791ms/step - loss: 0.3049 - acc: 0.8774 - val_loss: 0.6132 - val_acc: 0.7679
# Epoch 6/20
# 66/66 [==============================] - 52s 790ms/step - loss: 0.2976 - acc: 0.8821 - val_loss: 0.3943 - val_acc: 0.8368
# Epoch 7/20
# 66/66 [==============================] - 52s 790ms/step - loss: 0.2755 - acc: 0.8878 - val_loss: 0.4294 - val_acc: 0.8148
# Epoch 8/20
# 66/66 [==============================] - 52s 793ms/step - loss: 0.2671 - acc: 0.8944 - val_loss: 0.6717 - val_acc: 0.7454
# Epoch 9/20
# 66/66 [==============================] - 52s 792ms/step - loss: 0.2687 - acc: 0.8935 - val_loss: 0.4561 - val_acc: 0.8298
# Epoch 10/20
# 66/66 [==============================] - 52s 792ms/step - loss: 0.2512 - acc: 0.8969 - val_loss: 0.2670 - val_acc: 0.8940
# Epoch 11/20
# 66/66 [==============================] - 52s 794ms/step - loss: 0.2478 - acc: 0.8980 - val_loss: 0.7787 - val_acc: 0.6784
# Epoch 12/20
# 66/66 [==============================] - 52s 792ms/step - loss: 0.2416 - acc: 0.9022 - val_loss: 0.5712 - val_acc: 0.7234
# Epoch 13/20
# 66/66 [==============================] - 52s 794ms/step - loss: 0.2444 - acc: 0.9030 - val_loss: 0.5171 - val_acc: 0.7773
# Epoch 14/20
# 66/66 [==============================] - 52s 793ms/step - loss: 0.2289 - acc: 0.9088 - val_loss: 1.1517 - val_acc: 0.7384
# Epoch 15/20
# 66/66 [==============================] - 52s 790ms/step - loss: 0.2286 - acc: 0.9068 - val_loss: 0.4077 - val_acc: 0.8153
# Epoch 16/20
# 66/66 [==============================] - 52s 791ms/step - loss: 0.2226 - acc: 0.9122 - val_loss: 0.5182 - val_acc: 0.7632
# Epoch 17/20
# 66/66 [==============================] - 52s 791ms/step - loss: 0.2095 - acc: 0.9176 - val_loss: 0.6037 - val_acc: 0.7745
# Epoch 18/20
# 66/66 [==============================] - 52s 791ms/step - loss: 0.2039 - acc: 0.9208 - val_loss: 2.7153 - val_acc: 0.6789
# Epoch 19/20
# 66/66 [==============================] - 52s 790ms/step - loss: 0.2063 - acc: 0.9158 - val_loss: 1.4240 - val_acc: 0.6990
# Epoch 20/20
# 66/66 [==============================] - 52s 794ms/step - loss: 0.2045 - acc: 0.9188 - val_loss: 0.8850 - val_acc: 0.5166
# <keras.callbacks.History object at 0x7fb3804f2cf8>

# %%
plt.rcParams['figure.figsize'] = [10, 8]
plt.plot(model_senet.hist.history['acc'])
plt.plot(model_senet.hist.history['val_acc'])
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.rcParams['figure.figsize'] = [10, 8]
plt.plot(model_senet.hist.history['loss'])
plt.plot(model_senet.hist.history['val_loss'])
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %% [markdown]
# ### Fitting our pretrained models

# %% [markdown]
# Densenet

# %%
from keras.applications.densenet import DenseNet121

batch_size = 128
num_classes = 2

model_densenet = Sequential()
model_densenet.add(DenseNet121(include_top=False, pooling= 'max', weights = 'imagenet'))
model_densenet.add(BatchNormalization())
model_densenet.add(Activation("tanh"))
model_densenet.add(Dropout(0.40))
model_densenet.add(Dense(num_classes, activation = "sigmoid"))


model_densenet.compile(optimizer = "Adamax", loss = "categorical_crossentropy", 
                       metrics = ['mae', 'accuracy'])

datagen = ImageDataGenerator(featurewise_center=True,  # set input mean to 0 over the dataset
                             samplewise_center=False,  # set each sample mean to 0
                             featurewise_std_normalization=True,  # divide inputs by dataset std
                             samplewise_std_normalization=False,  # divide each input by its std
                             zca_whitening=False,  # apply ZCA whitening
                             zca_epsilon=1e-06,  # epsilon for ZCA whitening
                             rotation_range=0.2,  # randomly rotate images in 0 to 180 degrees
                             width_shift_range=0.1,  # randomly shift images horizontally
                             height_shift_range=0.1,  # randomly shift images vertically
                             shear_range=0.,  # set range for random shear
                             zoom_range=0.3,  # set range for random zoom
                             channel_shift_range=0,  # set range for random channel shifts
                             # set mode for filling points outside the input boundaries
                             fill_mode='nearest',
                             cval=0.,  # value used for fill_mode = "constant"
                             horizontal_flip=True,  # randomly flip images
                             vertical_flip=False,  # randomly flip images
                             # set rescaling factor (applied before any other transformation)
                             rescale=1./255,
                             # set function that will be applied on each input
                             preprocessing_function=None,
                             # image data format, either "channels_first" or "channels_last"
                             data_format=None,
                             # fraction of images reserved for validation (strictly between 0 and 1)
                             validation_split=0.0)
datagen.fit(x_train)
print(x_test.shape)
for i in range(len(x_test)):
    # this is what you are looking for
    x_test[i] = datagen.standardize(x_test[i])
print(x_test.shape)

print("*"*40 + "Densenet model" + "*"*40)
history = model_densenet.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                           verbose = 1,
                           epochs = epochs,
                           steps_per_epoch= x_train.shape[0] // batch_size, 
                            callbacks = [learning_rate_reduction],
                           validation_data = (x_test, y_test))
# Out:
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# (2133, 100, 100, 3)
# (2133, 100, 100, 3)
# ****************************************Densenet model****************************************
# Epoch 1/20
# 66/66 [==============================] - 63s 949ms/step - loss: 0.4487 - mean_absolute_error: 0.2988 - acc: 0.8008 - val_loss: 0.7375 - val_mean_absolute_error: 0.3101 - val_acc: 0.7604
# Epoch 2/20
# 66/66 [==============================] - 23s 341ms/step - loss: 0.3491 - mean_absolute_error: 0.2160 - acc: 0.8598 - val_loss: 1.1766 - val_mean_absolute_error: 0.3479 - val_acc: 0.6784
# Epoch 3/20
# 66/66 [==============================] - 24s 362ms/step - loss: 0.3036 - mean_absolute_error: 0.1763 - acc: 0.8803 - val_loss: 2.5707 - val_mean_absolute_error: 0.6375 - val_acc: 0.3479
# Epoch 4/20
# 66/66 [==============================] - 24s 360ms/step - loss: 0.2835 - mean_absolute_error: 0.1621 - acc: 0.8873 - val_loss: 1.4671 - val_mean_absolute_error: 0.3829 - val_acc: 0.6784
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# Epoch 5/20
# 66/66 [==============================] - 22s 341ms/step - loss: 0.2618 - mean_absolute_error: 0.1491 - acc: 0.8969 - val_loss: 1.1234 - val_mean_absolute_error: 0.4420 - val_acc: 0.5598
# Epoch 6/20
# 66/66 [==============================] - 24s 359ms/step - loss: 0.2452 - mean_absolute_error: 0.1398 - acc: 0.9028 - val_loss: 1.5512 - val_mean_absolute_error: 0.5167 - val_acc: 0.4707
# Epoch 7/20
# 66/66 [==============================] - 24s 364ms/step - loss: 0.2336 - mean_absolute_error: 0.1315 - acc: 0.9064 - val_loss: 0.9937 - val_mean_absolute_error: 0.3302 - val_acc: 0.6784
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 8/20
# 66/66 [==============================] - 24s 365ms/step - loss: 0.2172 - mean_absolute_error: 0.1234 - acc: 0.9144 - val_loss: 0.3478 - val_mean_absolute_error: 0.2237 - val_acc: 0.8556
# Epoch 9/20
# 66/66 [==============================] - 23s 356ms/step - loss: 0.2120 - mean_absolute_error: 0.1187 - acc: 0.9169 - val_loss: 0.3332 - val_mean_absolute_error: 0.2114 - val_acc: 0.8640
# Epoch 10/20
# 66/66 [==============================] - 24s 359ms/step - loss: 0.2012 - mean_absolute_error: 0.1148 - acc: 0.9151 - val_loss: 1.5380 - val_mean_absolute_error: 0.3212 - val_acc: 0.6784
# Epoch 11/20
# 66/66 [==============================] - 24s 364ms/step - loss: 0.1908 - mean_absolute_error: 0.1058 - acc: 0.9245 - val_loss: 0.6998 - val_mean_absolute_error: 0.3378 - val_acc: 0.6789
# Epoch 12/20
# 66/66 [==============================] - 24s 365ms/step - loss: 0.1819 - mean_absolute_error: 0.1035 - acc: 0.9277 - val_loss: 1.1993 - val_mean_absolute_error: 0.5057 - val_acc: 0.4566
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 13/20
# 66/66 [==============================] - 24s 367ms/step - loss: 0.1681 - mean_absolute_error: 0.0961 - acc: 0.9295 - val_loss: 0.4437 - val_mean_absolute_error: 0.2562 - val_acc: 0.8026
# Epoch 14/20
# 66/66 [==============================] - 24s 366ms/step - loss: 0.1615 - mean_absolute_error: 0.0916 - acc: 0.9361 - val_loss: 0.4632 - val_mean_absolute_error: 0.2531 - val_acc: 0.7656
# Epoch 15/20
# 66/66 [==============================] - 24s 364ms/step - loss: 0.1549 - mean_absolute_error: 0.0867 - acc: 0.9387 - val_loss: 0.3924 - val_mean_absolute_error: 0.2160 - val_acc: 0.8223
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 16/20
# 66/66 [==============================] - 24s 361ms/step - loss: 0.1449 - mean_absolute_error: 0.0827 - acc: 0.9427 - val_loss: 0.3815 - val_mean_absolute_error: 0.2154 - val_acc: 0.8233
# Epoch 17/20
# 66/66 [==============================] - 24s 365ms/step - loss: 0.1395 - mean_absolute_error: 0.0787 - acc: 0.9480 - val_loss: 0.5318 - val_mean_absolute_error: 0.3266 - val_acc: 0.7295
# Epoch 18/20
# 66/66 [==============================] - 24s 358ms/step - loss: 0.1370 - mean_absolute_error: 0.0770 - acc: 0.9463 - val_loss: 0.4511 - val_mean_absolute_error: 0.2502 - val_acc: 0.7797
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 19/20
# 66/66 [==============================] - 24s 362ms/step - loss: 0.1306 - mean_absolute_error: 0.0749 - acc: 0.9476 - val_loss: 0.3806 - val_mean_absolute_error: 0.2218 - val_acc: 0.8223
# Epoch 20/20
# 66/66 [==============================] - 24s 366ms/step - loss: 0.1314 - mean_absolute_error: 0.0751 - acc: 0.9494 - val_loss: 0.3780 - val_mean_absolute_error: 0.2230 - val_acc: 0.8247

# %%
plt.rcParams['figure.figsize'] = [10, 8]
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.rcParams['figure.figsize'] = [10, 8]
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %% [markdown]
# ### Defining ResNeXt50 model

# %%
'''ResNeXt models for Keras.
# Reference
- [Aggregated Residual Transformations for Deep Neural Networks](https://arxiv.org/pdf/1611.05431.pdf))
'''

CIFAR_TH_WEIGHTS_PATH = ''
CIFAR_TF_WEIGHTS_PATH = ''
CIFAR_TH_WEIGHTS_PATH_NO_TOP = ''
CIFAR_TF_WEIGHTS_PATH_NO_TOP = ''

IMAGENET_TH_WEIGHTS_PATH = ''
IMAGENET_TF_WEIGHTS_PATH = ''
IMAGENET_TH_WEIGHTS_PATH_NO_TOP = ''
IMAGENET_TF_WEIGHTS_PATH_NO_TOP = ''

# %%
def __create_res_next_imagenet(nb_classes, img_input, include_top, depth, cardinality=32, width=4,
                               weight_decay=5e-4, pooling=None):
    ''' Creates a ResNeXt model with specified parameters
    Args:
        nb_classes: Number of output classes
        img_input: Input tensor or layer
        include_top: Flag to include the last dense layer
        depth: Depth of the network. List of integers.
               Increasing cardinality improves classification accuracy,
        width: Width of the network.
        weight_decay: weight_decay (l2 norm)
        pooling: Optional pooling mode for feature extraction
            when `include_top` is `False`.
            - `None` means that the output of the model will be
                the 4D tensor output of the
                last convolutional layer.
            - `avg` means that global average pooling
                will be applied to the output of the
                last convolutional layer, and thus
                the output of the model will be a 2D tensor.
            - `max` means that global max pooling will
                be applied.
    Returns: a Keras Model
    '''

    if type(depth) is list or type(depth) is tuple:
        # If a list is provided, defer to user how many blocks are present
        N = list(depth)
    else:
        # Otherwise, default to 3 blocks each of default number of group convolution blocks
        N = [(depth - 2) // 9 for _ in range(3)]

    filters = cardinality * width
    filters_list = []

    for i in range(len(N)):
        filters_list.append(filters)
        filters *= 2  # double the size of the filters

    x = __initial_conv_block_imagenet(img_input, weight_decay)

    # block 1 (no pooling)
    for i in range(N[0]):
        x = __bottleneck_block(x, filters_list[0], cardinality, strides=1, weight_decay=weight_decay)

    N = N[1:]  # remove the first block from block definition list
    filters_list = filters_list[1:]  # remove the first filter from the filter list

    # block 2 to N
    for block_idx, n_i in enumerate(N):
        for i in range(n_i):
            if i == 0:
                x = __bottleneck_block(x, filters_list[block_idx], cardinality, strides=2,
                                       weight_decay=weight_decay)
            else:
                x = __bottleneck_block(x, filters_list[block_idx], cardinality, strides=1,
                                       weight_decay=weight_decay)

    if include_top:
        x = GlobalAveragePooling2D()(x)
        x = Dense(nb_classes, use_bias=False, kernel_regularizer=l2(weight_decay),
                  kernel_initializer='he_normal', activation='softmax')(x)
    else:
        if pooling == 'avg':
            x = GlobalAveragePooling2D()(x)
        elif pooling == 'max':
            x = GlobalMaxPooling2D()(x)

    return x

def __initial_conv_block_imagenet(input, weight_decay=5e-4):
    ''' Adds an initial conv block, with batch norm and relu for the inception resnext
    Args:
        input: input tensor
        weight_decay: weight decay factor
    Returns: a keras tensor
    '''
    channel_axis = 1 if K.image_data_format() == 'channels_first' else -1

    x = Conv2D(64, (7, 7), padding='same', use_bias=False, kernel_initializer='he_normal',
               kernel_regularizer=l2(weight_decay), strides=(2, 2))(input)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Activation('relu')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    return x

def __bottleneck_block(input, filters=64, cardinality=8, strides=1, weight_decay=5e-4):
    ''' Adds a bottleneck block
    Args:
        input: input tensor
        filters: number of output filters
        cardinality: cardinality factor described number of
            grouped convolutions
        strides: performs strided convolution for downsampling if > 1
        weight_decay: weight decay factor
    Returns: a keras tensor
    '''
    init = input

    grouped_channels = int(filters / cardinality)
    channel_axis = 1 if K.image_data_format() == 'channels_first' else -1

    # Check if input number of filters is same as 16 * k, else create convolution2d for this input
    if K.image_data_format() == 'channels_first':
        if init._keras_shape[1] != 2 * filters:
            init = Conv2D(filters * 2, (1, 1), padding='same', strides=(strides, strides),
                          use_bias=False, kernel_initializer='he_normal', kernel_regularizer=l2(weight_decay))(init)
            init = BatchNormalization(axis=channel_axis)(init)
    else:
        if init._keras_shape[-1] != 2 * filters:
            init = Conv2D(filters * 2, (1, 1), padding='same', strides=(strides, strides),
                          use_bias=False, kernel_initializer='he_normal', kernel_regularizer=l2(weight_decay))(init)
            init = BatchNormalization(axis=channel_axis)(init)

    x = Conv2D(filters, (1, 1), padding='same', use_bias=False,
               kernel_initializer='he_normal', kernel_regularizer=l2(weight_decay))(input)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Activation('relu')(x)

    x = __grouped_convolution_block(x, grouped_channels, cardinality, strides, weight_decay)

    x = Conv2D(filters * 2, (1, 1), padding='same', use_bias=False, kernel_initializer='he_normal',
               kernel_regularizer=l2(weight_decay))(x)
    x = BatchNormalization(axis=channel_axis)(x)

    x = add([init, x])
    x = Activation('relu')(x)

    return x


def __grouped_convolution_block(input, grouped_channels, cardinality, strides, weight_decay=5e-4):
    ''' Adds a grouped convolution block. It is an equivalent block from the paper
    Args:
        input: input tensor
        grouped_channels: grouped number of filters
        cardinality: cardinality factor describing the number of groups
        strides: performs strided convolution for downscaling if > 1
        weight_decay: weight decay term
    Returns: a keras tensor
    '''
    init = input
    channel_axis = 1 if K.image_data_format() == 'channels_first' else -1

    group_list = []

    if cardinality == 1:
        # with cardinality 1, it is a standard convolution
        x = Conv2D(grouped_channels, (3, 3), padding='same', use_bias=False, strides=(strides, strides),
                   kernel_initializer='he_normal', kernel_regularizer=l2(weight_decay))(init)
        x = BatchNormalization(axis=channel_axis)(x)
        x = Activation('relu')(x)
        return x

    for c in range(cardinality):
        x = Lambda(lambda z: z[:, :, :, c * grouped_channels:(c + 1) * grouped_channels]
        if K.image_data_format() == 'channels_last' else
        lambda z: z[:, c * grouped_channels:(c + 1) * grouped_channels, :, :])(input)

        x = Conv2D(grouped_channels, (3, 3), padding='same', use_bias=False, strides=(strides, strides),
                   kernel_initializer='he_normal', kernel_regularizer=l2(weight_decay))(x)

        group_list.append(x)

    group_merge = concatenate(group_list, axis=channel_axis)
    x = BatchNormalization(axis=channel_axis)(group_merge)
    x = Activation('relu')(x)

    return x

# %%
input_shape = (100, 100, 3)
num_classes = 2
batch_size = 128
# Data Augmentation
datagen = ImageDataGenerator(featurewise_center = False, samplewise_center = True,
                            featurewise_std_normalization = False, samplewise_std_normalization = True, 
                            zca_whitening = False, rotation_range = 0.3, zoom_range = 0.3, 
                            width_shift_range = 0.2, height_shift_range = 0.2, horizontal_flip = True, 
                            vertical_flip = False, rescale = 1./255)
datagen.fit(x_train)
print(x_test.shape)
for i in range(len(x_test)):
    x_test[i] = datagen.standardize(x_test[i])
print(x_test.shape)
# Out:
# (2133, 100, 100, 3)
# (2133, 100, 100, 3)

# %%
def ResNextImageNet(input_shape, depth, cardinality, width, weight_decay, pooling, classes, 
                    include_top= False, weights=None, input_tensor=None):
    """ Instantiate the ResNeXt architecture for the ImageNet dataset. Note that ,
        when using TensorFlow for best performance you should set
        `image_data_format="channels_last"` in your Keras config
        at ~/.keras/keras.json.
        The model are compatible with both
        TensorFlow and Theano. The dimension ordering
        convention used by the model is the one
        specified in your Keras config file.
        # Arguments
            depth: number or layers in the each block, defined as a list.
                ResNeXt-50 can be defined as [3, 4, 6, 3].
                ResNeXt-101 can be defined as [3, 4, 23, 3].
                Defaults is ResNeXt-50.
            cardinality: the size of the set of transformations
            width: multiplier to the ResNeXt width (number of filters)
            weight_decay: weight decay (l2 norm)
            include_top: whether to include the fully-connected
                layer at the top of the network.
            weights: `None` (random initialization) or `imagenet` (trained
                on ImageNet)
            input_tensor: optional Keras tensor (i.e. output of `layers.Input()`)
                to use as image input for the model.
            input_shape: optional shape tuple, only to be specified
                if `include_top` is False (otherwise the input shape
                has to be `(224, 224, 3)` (with `tf` dim ordering)
                or `(3, 224, 224)` (with `th` dim ordering).
                It should have exactly 3 inputs channels,
                and width and height should be no smaller than 8.
                E.g. `(200, 200, 3)` would be one valid value.
            pooling: Optional pooling mode for feature extraction
                when `include_top` is `False`.
                - `None` means that the output of the model will be
                    the 4D tensor output of the
                    last convolutional layer.
                - `avg` means that global average pooling
                    will be applied to the output of the
                    last convolutional layer, and thus
                    the output of the model will be a 2D tensor.
                - `max` means that global max pooling will
                    be applied.
            classes: optional number of classes to classify images
                into, only to be specified if `include_top` is True, and
                if no `weights` argument is specified.
        # Returns
            A Keras model instance.
        """

    if weights not in {'imagenet', None}:
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization) or `imagenet` '
                         '(pre-training on ImageNet).')

    if weights == 'imagenet' and include_top and classes != 1000:
        raise ValueError('If using `weights` as imagenet with `include_top`'
                         ' as true, `classes` should be 1000')

    if type(depth) == int and (depth - 2) % 9 != 0:
        raise ValueError('Depth of the network must be such that (depth - 2)'
                         'should be divisible by 9.')
    # Determine proper input shape
#     input_shape = _obtain_input_shape(input_shape,
#                                       default_size=224,
#                                       min_size=112,
#                                       data_format=K.image_data_format(),
#                                       require_flatten=include_top)

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor

    x = __create_res_next_imagenet(classes, img_input, include_top, depth, cardinality, width,
                                   weight_decay, pooling)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = img_input
    # Create model.
    model = Model(inputs, x, name= 'resnext')

    # load weights
    if weights == 'imagenet':
        if (depth == [3, 4, 6, 3]) and (cardinality == 32) and (width == 4):
            # Default parameters match. Weights for this model exist:

            if K.image_data_format() == 'channels_first':
                if include_top:
                    weights_path = get_file('resnext_imagenet_32_4_th_dim_ordering_th_kernels.h5',
                                            IMAGENET_TH_WEIGHTS_PATH,
                                            cache_subdir='models')
                else:
                    weights_path = get_file('resnext_imagenet_32_4_th_dim_ordering_th_kernels_no_top.h5',
                                            IMAGENET_TH_WEIGHTS_PATH_NO_TOP,
                                            cache_subdir='models')

                model.load_weights(weights_path)

                if K.backend() == 'tensorflow':
                    warnings.warn('You are using the TensorFlow backend, yet you '
                                  'are using the Theano '
                                  'image dimension ordering convention '
                                  '(`image_dim_ordering="th"`). '
                                  'For best performance, set '
                                  '`image_dim_ordering="tf"` in '
                                  'your Keras config '
                                  'at ~/.keras/keras.json.')
                    convert_all_kernels_in_model(model)
            else:
                if include_top:
                    weights_path = get_file('resnext_imagenet_32_4_tf_dim_ordering_tf_kernels.h5',
                                            IMAGENET_TF_WEIGHTS_PATH,
                                            cache_subdir='models')
                else:
                    weights_path = get_file('resnext_imagenet_32_4_tf_dim_ordering_tf_kernels_no_top.h5',
                                            IMAGENET_TF_WEIGHTS_PATH_NO_TOP,
                                            cache_subdir='models')

                model.load_weights(weights_path)

                if K.backend() == 'theano':
                    convert_all_kernels_in_model(model)

    return model

# %%
model_resnext = Sequential()
model_resnext.add(ResNextImageNet(input_shape= input_shape, depth=[3, 4, 6, 3], cardinality=32, width=4, 
                                weight_decay=5e-4, include_top= False, weights=None, input_tensor=None, 
                                pooling= 'max', classes= 1000))
model_resnext.add(Dropout(.3))
model_resnext.add(Dense(num_classes, activation = "sigmoid"))

# %%
model_resnext.compile(optimizer = "Adamax", loss = 'categorical_crossentropy', metrics = ['mae', 'accuracy'])

# %%
history = model_resnext.fit_generator(datagen.flow(x_train, y_train, batch_size = batch_size), verbose = 1, 
                           epochs = epochs,
                           steps_per_epoch= x_train.shape[0] // batch_size, 
                            callbacks = [learning_rate_reduction],
                           validation_data = (x_test, y_test))
# Out:
# Epoch 1/20
# 66/66 [==============================] - 103s 2s/step - loss: 28.5445 - mean_absolute_error: 0.4209 - acc: 0.6716 - val_loss: 26.2702 - val_mean_absolute_error: 0.3483 - val_acc: 0.6784
# Epoch 2/20
# 66/66 [==============================] - 33s 499ms/step - loss: 25.2135 - mean_absolute_error: 0.3905 - acc: 0.7147 - val_loss: 25.0187 - val_mean_absolute_error: 0.3384 - val_acc: 0.6784
# Epoch 3/20
# 66/66 [==============================] - 33s 493ms/step - loss: 23.6274 - mean_absolute_error: 0.3725 - acc: 0.7260 - val_loss: 23.6169 - val_mean_absolute_error: 0.3506 - val_acc: 0.6784
# Epoch 4/20
# 66/66 [==============================] - 33s 495ms/step - loss: 22.2496 - mean_absolute_error: 0.3693 - acc: 0.7315 - val_loss: 21.9298 - val_mean_absolute_error: 0.3628 - val_acc: 0.6784
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# Epoch 5/20
# 66/66 [==============================] - 32s 491ms/step - loss: 21.2459 - mean_absolute_error: 0.3533 - acc: 0.7415 - val_loss: 21.2348 - val_mean_absolute_error: 0.3546 - val_acc: 0.6784
# Epoch 6/20
# 66/66 [==============================] - 33s 494ms/step - loss: 20.6134 - mean_absolute_error: 0.3531 - acc: 0.7378 - val_loss: 20.5233 - val_mean_absolute_error: 0.3592 - val_acc: 0.6784
# Epoch 7/20
# 66/66 [==============================] - 32s 490ms/step - loss: 19.9771 - mean_absolute_error: 0.3508 - acc: 0.7440 - val_loss: 19.9531 - val_mean_absolute_error: 0.3569 - val_acc: 0.6784
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 8/20
# 66/66 [==============================] - 32s 492ms/step - loss: 19.4987 - mean_absolute_error: 0.3462 - acc: 0.7412 - val_loss: 19.6440 - val_mean_absolute_error: 0.3527 - val_acc: 0.6784
# Epoch 9/20
# 66/66 [==============================] - 33s 495ms/step - loss: 19.1770 - mean_absolute_error: 0.3469 - acc: 0.7394 - val_loss: 19.2620 - val_mean_absolute_error: 0.3563 - val_acc: 0.6784
# Epoch 10/20
# 66/66 [==============================] - 33s 494ms/step - loss: 18.8442 - mean_absolute_error: 0.3438 - acc: 0.7467 - val_loss: 18.9944 - val_mean_absolute_error: 0.3515 - val_acc: 0.6784
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 11/20
# 66/66 [==============================] - 32s 492ms/step - loss: 18.5853 - mean_absolute_error: 0.3418 - acc: 0.7427 - val_loss: 18.8173 - val_mean_absolute_error: 0.3501 - val_acc: 0.6784
# Epoch 12/20
# 66/66 [==============================] - 33s 495ms/step - loss: 18.4135 - mean_absolute_error: 0.3455 - acc: 0.7431 - val_loss: 18.6277 - val_mean_absolute_error: 0.3501 - val_acc: 0.6784
# Epoch 13/20
# 66/66 [==============================] - 33s 495ms/step - loss: 18.2215 - mean_absolute_error: 0.3392 - acc: 0.7431 - val_loss: 18.4078 - val_mean_absolute_error: 0.3518 - val_acc: 0.6784
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 14/20
# 66/66 [==============================] - 33s 494ms/step - loss: 18.0747 - mean_absolute_error: 0.3428 - acc: 0.7410 - val_loss: 18.3178 - val_mean_absolute_error: 0.3498 - val_acc: 0.6784
# Epoch 15/20
# 66/66 [==============================] - 33s 495ms/step - loss: 17.9724 - mean_absolute_error: 0.3418 - acc: 0.7482 - val_loss: 18.2457 - val_mean_absolute_error: 0.3475 - val_acc: 0.6784
# Epoch 16/20
# 66/66 [==============================] - 33s 494ms/step - loss: 17.8575 - mean_absolute_error: 0.3339 - acc: 0.7446 - val_loss: 18.1267 - val_mean_absolute_error: 0.3486 - val_acc: 0.6784
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 17/20
# 66/66 [==============================] - 32s 490ms/step - loss: 17.7739 - mean_absolute_error: 0.3364 - acc: 0.7456 - val_loss: 18.0912 - val_mean_absolute_error: 0.3482 - val_acc: 0.6784
# Epoch 18/20
# 66/66 [==============================] - 32s 492ms/step - loss: 17.7159 - mean_absolute_error: 0.3356 - acc: 0.7424 - val_loss: 18.0034 - val_mean_absolute_error: 0.3494 - val_acc: 0.6784
# Epoch 19/20
# 66/66 [==============================] - 33s 494ms/step - loss: 17.6506 - mean_absolute_error: 0.3354 - acc: 0.7479 - val_loss: 17.9392 - val_mean_absolute_error: 0.3492 - val_acc: 0.6784
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 20/20
# 66/66 [==============================] - 32s 491ms/step - loss: 17.6027 - mean_absolute_error: 0.3350 - acc: 0.7437 - val_loss: 17.8991 - val_mean_absolute_error: 0.3497 - val_acc: 0.6784

# %%
plt.rcParams['figure.figsize'] = [10, 8]
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.rcParams['figure.figsize'] = [10, 8]
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
from keras.applications import VGG19
model_vgg19 = Sequential()
model_vgg19.add(VGG19(include_top= False, pooling = "max", weights = "imagenet"))
model_vgg19.add(Dense(num_classes, activation = "softmax"))
model_vgg19.layers[0].trainable = False
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step

# %%
# Compile the pretrained models

model_vgg19.compile(optimizer = "Adamax", loss = "categorical_crossentropy", metrics = ['mae', 'accuracy'])


datagen = ImageDataGenerator(featurewise_center = False, samplewise_center = True,
                            featurewise_std_normalization = False, samplewise_std_normalization = True, 
                            zca_whitening = False, rotation_range = 0, zoom_range = 0.3, 
                            width_shift_range = 0.2, height_shift_range = 0.2, horizontal_flip = False, 
                            vertical_flip = False, rescale = 1./255)
datagen.fit(x_train)
print(x_test.shape)
for i in range(len(x_test)):
    x_test[i] = datagen.standardize(x_test[i])
print(x_test.shape)
# Out:
# (2133, 100, 100, 3)
# (2133, 100, 100, 3)

# %%
import random
random.seed(1234)
batch_size = 128
num_classes = 2
epochs = 10
print("*"*40 + "VGG19 model" + "*"*40)
history = model_vgg19.fit_generator(datagen.flow(x_train, y_train, batch_size= batch_size),
                           verbose = 1,
                           epochs = epochs,
                           steps_per_epoch= x_train.shape[0] // batch_size, 
                            callbacks = [learning_rate_reduction],
                           validation_data = (x_test, y_test))
# Out:
# ****************************************VGG19 model****************************************
# Epoch 1/10
# 66/66 [==============================] - 42s 629ms/step - loss: 0.6292 - mean_absolute_error: 0.4211 - acc: 0.6780 - val_loss: 0.6122 - val_mean_absolute_error: 0.4454 - val_acc: 0.6784
# Epoch 2/10
# 66/66 [==============================] - 19s 282ms/step - loss: 0.5511 - mean_absolute_error: 0.3794 - acc: 0.7412 - val_loss: 0.6175 - val_mean_absolute_error: 0.4543 - val_acc: 0.6826
# Epoch 3/10
# 66/66 [==============================] - 20s 308ms/step - loss: 0.5314 - mean_absolute_error: 0.3617 - acc: 0.7521 - val_loss: 0.6113 - val_mean_absolute_error: 0.4492 - val_acc: 0.6817
# Epoch 4/10
# 66/66 [==============================] - 20s 306ms/step - loss: 0.5260 - mean_absolute_error: 0.3530 - acc: 0.7551 - val_loss: 0.6559 - val_mean_absolute_error: 0.4782 - val_acc: 0.6404
# Epoch 5/10
# 66/66 [==============================] - 21s 315ms/step - loss: 0.5207 - mean_absolute_error: 0.3472 - acc: 0.7577 - val_loss: 0.6783 - val_mean_absolute_error: 0.4882 - val_acc: 0.5626
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# Epoch 6/10
# 66/66 [==============================] - 19s 281ms/step - loss: 0.5119 - mean_absolute_error: 0.3437 - acc: 0.7649 - val_loss: 0.6750 - val_mean_absolute_error: 0.4866 - val_acc: 0.5706
# Epoch 7/10
# 66/66 [==============================] - 21s 311ms/step - loss: 0.5079 - mean_absolute_error: 0.3381 - acc: 0.7682 - val_loss: 0.6700 - val_mean_absolute_error: 0.4842 - val_acc: 0.5874
# Epoch 8/10
# 66/66 [==============================] - 20s 307ms/step - loss: 0.5078 - mean_absolute_error: 0.3386 - acc: 0.7654 - val_loss: 0.6987 - val_mean_absolute_error: 0.4960 - val_acc: 0.4984
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 9/10
# 66/66 [==============================] - 20s 307ms/step - loss: 0.5094 - mean_absolute_error: 0.3380 - acc: 0.7666 - val_loss: 0.6854 - val_mean_absolute_error: 0.4906 - val_acc: 0.5387
# Epoch 10/10
# 66/66 [==============================] - 20s 309ms/step - loss: 0.5055 - mean_absolute_error: 0.3355 - acc: 0.7670 - val_loss: 0.7113 - val_mean_absolute_error: 0.5005 - val_acc: 0.4679

# %%
plt.rcParams['figure.figsize'] = [10, 8]
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.rcParams['figure.figsize'] = [10, 8]
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
from os import makedirs
makedirs('models')
# fit and save models
filename = 'models/model_caps.h5'
model_caps.save(filename)
print('>Saved %s' % filename)
filename = 'models/model_densenet.h5'
model_densenet.save(filename)
print('>Saved %s' % filename)
filename = 'models/model_VGG19.h5'
model_vgg19.save(filename)
print('>Saved %s' % filename)
filename = 'models/model_resnext.h5'
model_resnext.save(filename)
print('>Saved %s' % filename)
# Out:
# >Saved models/model_caps.h5
# >Saved models/model_densenet.h5
# >Saved models/model_VGG19.h5
# >Saved models/model_resnext.h5

# %%
print("Metrics for Capsnet model", model_caps.metrics_names)
print("Capsnet model metrics on test data: ", model_caps.evaluate(x_test, y_test, verbose = 0))
print("Metrics for VGG19 model", model_vgg19.metrics_names)
print("VGG19 model metrics on test data: ", model_vgg19.evaluate(x_test, y_test, verbose = 0))
print("Metrics for Resnext model", model_resnext.metrics_names)
print("Resnext model metrics on test data: ", model_resnext.evaluate(x_test, y_test, verbose = 0))
print("Metrics for Densenet model", model_densenet.metrics_names)
print("Densenet model metrics on test data: ", model_densenet.evaluate(x_test, y_test, verbose = 0))
# Out:
# Metrics for Capsnet model ['loss', 'mean_absolute_error', 'acc']
# Capsnet model metrics on test data:  [0.5276840893360465, 0.6170526075910863, 0.32161275206235895]
# Metrics for VGG19 model ['loss', 'mean_absolute_error', 'acc']
# VGG19 model metrics on test data:  [0.7112664405694882, 0.5004638253776221, 0.4678856071680295]
# Metrics for Resnext model ['loss', 'mean_absolute_error', 'acc']
# Resnext model metrics on test data:  [17.897874395779137, 0.3498552857963233, 0.6783872482310536]
# Metrics for Densenet model ['loss', 'mean_absolute_error', 'acc']
# Densenet model metrics on test data:  [1.3028360340889216, 0.5301880215011289, 0.32161275206235895]

# %%
members = []
members.append(model_caps)
members.append(model_vgg19)
members.append(model_densenet)
members.append(model_resnext)

# %%
for model in members:
    acc = model.evaluate(x_test, y_test, verbose=0)[-1]
    print('Model Accuracy: %.3f' % acc)
# Out:
# Model Accuracy: 0.322
# Model Accuracy: 0.468
# Model Accuracy: 0.322
# Model Accuracy: 0.678

# %%
# create stacked model input dataset as outputs from the ensemble
def stacked_dataset(members, inputX):
    stackX = None
    for model in members:
        # make prediction
        yhat = model.predict(inputX, verbose=0)
        # stack predictions into [rows, members, probabilities]
        if stackX is None:
            stackX = yhat
        else:
            stackX = np.dstack((stackX, yhat))
    # flatten predictions to [rows, members x probabilities]
    stackX = stackX.reshape((stackX.shape[0], stackX.shape[1]*stackX.shape[2]))
    return stackX

# fit a model based on the outputs from the ensemble members
def fit_stacked_model(members, inputX, inputy):
    # create dataset using ensemble
    stackedX = stacked_dataset(members, inputX)
    # fit standalone model
    model = LogisticRegression()
    model.fit(stackedX, inputy)
    return model

# fit stacked model using the ensemble
model = fit_stacked_model(members, x_test, y_dopetest)

# make a prediction with the stacked model
def stacked_prediction(members, model, inputX):
    # create dataset using ensemble
    stackedX = stacked_dataset(members, inputX)
    # make a prediction
    yhat = model.predict(stackedX)
    return yhat

# evaluate model on test set
yhat = stacked_prediction(members, model, x_test)
acc = accuracy_score(y_dopetest, yhat)
print('Stacked Test Accuracy: %.3f' % acc)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Stacked Test Accuracy: 0.678

# %% [markdown]
# | Model/Architecture | Type | Accuracy(in %) |
# | --- | --- | --- |
# | SeResNext | Raw | ~90 |
# | ResNet50 | Raw | ~68 |
# | Capsnet | Raw | ~80 |
# | VGG19 | Pre-Trained | ~79 |
# | Densenet | Pre-Trained | ~64 |

# %% [markdown]
# Dataset Reference: [Codalab Competition](https://competitions.codalab.org/competitions/20429#learn_the_details-terms_and_conditions)
